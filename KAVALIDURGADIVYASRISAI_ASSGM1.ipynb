# %%
import pandas as pd
import numpy as np
import random
df=pd.DataFrame(np.random.rand(4,4))
df
# Out:
#           0         1         2         3
# 0  0.338483  0.597305  0.221023  0.379170
# 1  0.425800  0.261942  0.370813  0.165196
# 2  0.965641  0.404063  0.121097  0.613942
# 3  0.465903  0.789619  0.260722  0.653798

# %%
df.columns=['Random value 1','Random value 2','Random value 3','Random value 4']
df
# Out:
#    Random value 1  Random value 2  Random value 3  Random value 4
# 0        0.338483        0.597305        0.221023        0.379170
# 1        0.425800        0.261942        0.370813        0.165196
# 2        0.965641        0.404063        0.121097        0.613942
# 3        0.465903        0.789619        0.260722        0.653798

# %%
df.describe()
# Out:
#        Random value 1  Random value 2  Random value 3  Random value 4
# count        4.000000        4.000000        4.000000        4.000000
# mean         0.548957        0.513232        0.243414        0.453026
# std          0.282837        0.229872        0.103268        0.226939
# min          0.338483        0.261942        0.121097        0.165196
# 25%          0.403971        0.368533        0.196042        0.325676
# 50%          0.445851        0.500684        0.240873        0.496556
# 75%          0.590838        0.645383        0.288245        0.623906
# max          0.965641        0.789619        0.370813        0.653798

# %%
print(df.info())
df.isnull().any()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Random value 1  4 non-null      float64
#  1   Random value 2  4 non-null      float64
#  2   Random value 3  4 non-null      float64
#  3   Random value 4  4 non-null      float64
# dtypes: float64(4)
# memory usage: 256.0 bytes
# None
# Random value 1    False
# Random value 2    False
# Random value 3    False
# Random value 4    False
# dtype: bool

# %%
print(df.loc[0:3,'Random value 2':'Random value 3'])
df.iloc[0:4,1:3]
# Out:
#    Random value 2  Random value 3
# 0        0.597305        0.221023
# 1        0.261942        0.370813
# 2        0.404063        0.121097
# 3        0.789619        0.260722
#    Random value 2  Random value 3
# 0        0.597305        0.221023
# 1        0.261942        0.370813
# 2        0.404063        0.121097
# 3        0.789619        0.260722
